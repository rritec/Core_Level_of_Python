# %% [markdown]
# # Filter <code>DataFrame</code> data
# --------------------
# 1. <code>DataFrame</code> is equal to `Table`.
# 2. In R/Python/Scala table is called as <code>DataFrame</code>
# 2. `rows` are equal `Observations/samples`
# 3. `columns` are equal to `Features/variables/dimensions`

# %% [markdown]
# ## Create a simple <code>DataFrame</code> by importing csv file
# - [Visit pandas website for more info ](http://pandas.pydata.org/)
# - pandas package will be covered in Level 3

# %%
import pandas as pd # pandas is useful to analysis ,it is similar to sql

# %%
df = pd.read_csv("C:\\Users\\ramreddymyla\\Google Drive\\01 DS ML DL NLP and AI With Python Lab Copy\\02 Lab Data\\Python\\brics.CSV",
                 index_col=0)

# %%
df
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.population
# Out:
# BR     200.40
# RU     143.50
# IN    1252.00
# CH    1357.00
# SA      52.98
# Name: population, dtype: float64

# %%
df.population>250 # condition
# Out:
# BR    False
# RU    False
# IN     True
# CH     True
# SA    False
# Name: population, dtype: bool

# %%
df[df.population>250] # object[condition]
# Out:
#    country    capital   area  population
# IN   India  New Delhi  3.286      1252.0
# CH   China    Beijing  9.597      1357.0

# %%
type(df.population)
# Out:
# pandas.core.series.Series
