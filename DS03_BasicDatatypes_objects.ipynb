# %% [markdown]
# # `Basic Data Types`
# -----------
# - We have `5` types of basic datatypes
# - Numbers
#     - int
#     - float
#     - complex
# - str
# - bool

# %% [markdown]
# ## Numbers
# ------------

# %% [markdown]
# ### Integer data type

# %%
a_int = 13 # in java int a=12;

# %%
a_int
# Out:
# 13

# %%
type(a_int) # in case of r language class
# Out:
# int

# %% [markdown]
# #### example 2:

# %%
x = 3

# %%
print(x)
# Out:
# 3

# %%
type(x)
# Out:
# int

# %% [markdown]
# ### Float data type

# %%
a_float = 10.33

# %%
a_float
# Out:
# 10.33

# %%
type(a_float)
# Out:
# float

# %% [markdown]
# #### example 2:

# %%
y = 1.2

# %%
y
# Out:
# 1.2

# %%
type(y)
# Out:
# float

# %% [markdown]
# ### Complex number data type

# %%
a_complex = 1+2J # in case of R lang 1 +2i

# %%
a_complex
# Out:
# (1+2j)

# %%
type(a_complex)
# Out:
# complex

# %% [markdown]
# #### example 2:

# %%
z=1+10J

# %%
z
# Out:
# (1+10j)

# %%
type(z)
# Out:
# complex

# %% [markdown]
# ## String data type
# ----------------
# - To define str ,we can use either "" or ''
# - To define multiline string use """""" or ''''''

# %%
a_str = 'Ram'

# %%
a_str
# Out:
# 'Ram'

# %%
type(a_str)
# Out:
# str

# %% [markdown]
# ### example 2:

# %%
w = "python"

# %%
w
# Out:
# 'python'

# %%
type(w)
# Out:
# str

# %%
ml="""It is a multiline string,we should use three times double quotes or three times single qutos
then it will treat as string"""

# %%
ml
# Out:
# 'It is a multiline string,we should use three times double quotes or three times single qutos\nthen it will treat as string'

# %%
type(ml)
# Out:
# str

# %% [markdown]
# ## Boolian data type
# ----------

# %%
a_bool = True # in case of r language a_bool = TRUE

# %%
a_bool
# Out:
# True

# %%
type(a_bool)
# Out:
# bool

# %% [markdown]
# #### example 2:

# %%
b = False

# %%
b
# Out:
# False

# %%
type(b)
# Out:
# bool
