# %% [markdown]
# # Mutable Vs Immutable
# - **Mutable** : Items of object can be changed in **same memory location**
#
# - **Immutable** : Items of object can not be changed
#
# - string items are mutable or immutable ??
#
#     <input type="radio" disabled> Mutable
#     <input type="radio" disabled checked> Immutable
#
#
# - list items are mutable or immutable ??
#
#     <input type="radio" disabled checked> Mutable
#     <input type="radio" disabled > Immutable

# %% [markdown]
# ## 1. Working with `Str`

# %%
a_str ='python'

# %%
a_str[0]
# Out:
# 'p'

# %% [markdown]
# > Can we replace `p with J` ?

# %%
a_str[0] = 'j'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-91f492690cee> in <module>()
# ----> 1 a_str[0] = 'j'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## 2. Working with list

# %%
a_list = [10,20,30,40]

# %%
type(a_list)
# Out:
# list

# %%
a_list
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# > can we replace `10 with 1000` ?

# %%
a_list[0] = 1000

# %%
a="python"

# %%
a
# Out:
# 'python'

# %%
b="ml"

# %%
a+b
# Out:
# 'pythonml'

# %%
10+20
# Out:
# 30
